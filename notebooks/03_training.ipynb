# %%
# %cd C:\Users\blake\DSDA385\MIND_Recommender

from src.train import train
from src.evaluate import evaluate

modelgen, val_loadergen, devicegen = train(NAME='gen')
evaluate(model=modelgen, val_loader=val_loadergen, device=devicegen)
# Out:
# C:\Users\blake\DSDA385\MIND_Recommender
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\blake\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\blake\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Calling Preprocess
# Vocabulary size: 20774
# Loading Glove
# Found 19069/20774 words in GloVe
# Vocabulary size: 18776
# Epoch 1/5, Loss: 1.4405
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 6
#       2
#       3 from src.train import train
#       4 from src.evaluate import evaluate
#       5
# ----> 6 modelgen, val_loadergen, devicegen = train(NAME='gen')
#       7 evaluate(model=modelgen, val_loader=val_loadergen, device=devicegen)
#
# ...

# %%
modelshort, val_loadershort, deviceshort = train(NAME='short', MAX_HISTORY=25, MAX_TITLE_LEN=15)
evaluate(model=modelshort, val_loader=val_loadershort, device=deviceshort)

# %%
modelneg, val_loaderneg, deviceneg = train(NAME='neg', NEG_SAMPLE_K=8)
evaluate(model=modelneg, val_loader=val_loaderneg, device=deviceneg)
