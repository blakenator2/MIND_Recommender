# %%
# %cd C:\Users\blake\DSDA385\MIND_Recommender

from src.train import train
train(NAME='gen')
# Out:
# C:\Users\blake\DSDA385\MIND_Recommender
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\blake\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\blake\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Calling Preprocess
# Vocabulary size: 20774
# Loading Glove
# Found 19069/20774 words in GloVe
# Vocabulary size: 18776
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       2
#       3 from src.train import train
#       4 from src.evaluate import evaluate
#       5
# ----> 6 modelgen, val_loadergen, devicegen = train(NAME='gen')
#       7 evaluate(model=modelgen, val_loader=val_loadergen, device=devicegen)
#
# File ~\DSDA385\MIND_Recommender\src\train.py:32, in train(NAME, BATCH_SIZE, LEARNING_RATE, EPOCHS, NEG_SAMPLE_K, MAX_HISTORY, MAX_TITLE_LEN, NUM_HEADS, HEAD_DIM)
#      28 hist_mask = batch['hist_mask'].to(device)
#      31 optimizer.zero_grad()
# ---> 32 scores = model(history, candidates, hist_mask)
#      35 # labels[:,0] is always the positive (index 0)
#      36 target = torch.zeros(scores.size(0),
#      37         dtype=torch.long).to(device)
#
# File c:\Users\blake\DSDA385\MIND_Recommender\.venv\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File c:\Users\blake\DSDA385\MIND_Recommender\.venv\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~\DSDA385\MIND_Recommender\src\model.py:27, in NRMSModel.forward(self, history_ids, candidate_ids, hist_mask)
#      25 # Encode clicked news history
#      26 hist_flat = history_ids.view(-1, tlen)
# ---> 27 hist_vecs = self.news_encoder(hist_flat)
#      28 hist_vecs = hist_vecs.view(batch, hist_len, -1)
#      31 # Encode candidate news
#
# File c:\Users\blake\DSDA385\MIND_Recommender\.venv\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File c:\Users\blake\DSDA385\MIND_Recommender\.venv\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~\DSDA385\MIND_Recommender\src\news_encoder.py:44, in NewsEncoder.forward(self, title_ids)
#      42 x = self.dropout(self.word_embed(title_ids))
#      43 x = self.proj(x)
# ---> 44 x, _ = self.multihead_attn(x, x, x)
#      45 x = self.dropout(x)
#      46 news_vec = self.additive_attn(x) # (batch, attn_dim)
#
# File c:\Users\blake\DSDA385\MIND_Recommender\.venv\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File c:\Users\blake\DSDA385\MIND_Recommender\.venv\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File c:\Users\blake\DSDA385\MIND_Recommender\.venv\Lib\site-packages\torch\nn\modules\activation.py:1492, in MultiheadAttention.forward(self, query, key, value, key_padding_mask, need_weights, attn_mask, average_attn_weights, is_causal)
#    1466     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1467         query,
#    1468         key,
#    (...)   1489         is_causal=is_causal,
#    1490     )
#    1491 else:
# -> 1492     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1493         query,
#    1494         key,
#    1495         value,
#    1496         self.embed_dim,
#    1497         self.num_heads,
#    1498         self.in_proj_weight,
#    1499         self.in_proj_bias,
#    1500         self.bias_k,
#    1501         self.bias_v,
#    1502         self.add_zero_attn,
#    1503         self.dropout,
#    1504         self.out_proj.weight,
#    1505         self.out_proj.bias,
#    1506         training=self.training,
#    1507         key_padding_mask=key_padding_mask,
#    1508         need_weights=need_weights,
#    1509         attn_mask=attn_mask,
#    1510         average_attn_weights=average_attn_weights,
#    1511         is_causal=is_causal,
#    1512     )
#    1513 if self.batch_first and is_batched:
#    1514     return attn_output.transpose(1, 0), attn_output_weights
#
# File c:\Users\blake\DSDA385\MIND_Recommender\.venv\Lib\site-packages\torch\nn\functional.py:6478, in multi_head_attention_forward(query, key, value, embed_dim_to_check, num_heads, in_proj_weight, in_proj_bias, bias_k, bias_v, add_zero_attn, dropout_p, out_proj_weight, out_proj_bias, training, key_padding_mask, need_weights, attn_mask, use_separate_proj_weight, q_proj_weight, k_proj_weight, v_proj_weight, static_k, static_v, average_attn_weights, is_causal)
#    6474     if in_proj_weight is None:
#    6475         raise AssertionError(
#    6476             "use_separate_proj_weight is False but in_proj_weight is None"
#    6477         )
# -> 6478     q, k, v = _in_projection_packed(query, key, value, in_proj_weight, in_proj_bias)
#    6479 else:
#    6480     if q_proj_weight is None:
#
# File c:\Users\blake\DSDA385\MIND_Recommender\.venv\Lib\site-packages\torch\nn\functional.py:5836, in _in_projection_packed(q, k, v, w, b)
#    5833 if k is v:
#    5834     if q is k:
#    5835         # self-attention
# -> 5836         proj = linear(q, w, b)
#    5837         # reshape to 3, E and not E, 3 is deliberate for better memory coalescing and keeping same order as chunk()
#    5838         proj = (
#    5839             proj.unflatten(-1, (3, E))
#    5840             .unsqueeze(0)
#    (...)   5843             .contiguous()
#    5844         )
#
# KeyboardInterrupt:

# %%
# %cd C:\Users\blake\DSDA385\MIND_Recommender
from src.train import train
train(NAME='short', MAX_HISTORY=25, MAX_TITLE_LEN=15)
# Epoch 5/5, Loss: 1.2775
# AUC:     0.5081
# MRR:     0.4660
# nDCG@5:  0.5967
# nDCG@10: 0.5967
# Out:
# C:\Users\blake\DSDA385\MIND_Recommender
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\blake\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\blake\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Calling Preprocess
# Vocabulary size: 20774
# Loading Glove
# Found 19069/20774 words in GloVe
# Vocabulary size: 18776
# Epoch 1/5, Loss: 1.4274
# Epoch 2/5, Loss: 1.3385
# Epoch 3/5, Loss: 1.3104
# Epoch 4/5, Loss: 1.2923
# Epoch 5/5, Loss: 1.2775
# AUC:     0.5081
# MRR:     0.4660
# nDCG@5:  0.5967
# nDCG@10: 0.5967

# %%
# %cd C:\Users\blake\DSDA385\MIND_Recommender
from src.train import train
train(NAME='neg', NEG_SAMPLE_K=8)
# Epoch 5/5, Loss: 1.2995
# AUC:     0.7582
# MRR:     0.4657
# nDCG@5:  0.5968
# nDCG@10: 0.5968
# Out:
# C:\Users\blake\DSDA385\MIND_Recommender
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\blake\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\blake\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Calling Preprocess
# Vocabulary size: 20774
# Loading Glove
# Found 19069/20774 words in GloVe
# Vocabulary size: 18776
# Epoch 1/5, Loss: 1.4692
# Epoch 2/5, Loss: 1.3729
# Epoch 3/5, Loss: 1.3460
# Epoch 4/5, Loss: 1.3207
# Epoch 5/5, Loss: 1.2995
# AUC:     0.7582
# MRR:     0.4657
# nDCG@5:  0.5968
# nDCG@10: 0.5968
